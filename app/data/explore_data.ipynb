# %%
import pandas as pd

# %%
import os
useful_files = [ f for f in os.listdir() if f.endswith(".tsv")]

# %%
#basics =  pd.read_table('name.basics.tsv/data.tsv',nrows=4)

# %%
#basics.head()

# %%
title_akas =  pd.read_table('title.akas.tsv/data.tsv',nrows=4)

# %%
title_akas
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay             \N                0
# 1           \N  literal title                0
# 2  imdbDisplay             \N                0
# 3  imdbDisplay             \N                0

# %%
title_basics =  pd.read_table('title.basics.tsv/data.tsv',nrows=1000)

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
#
#    isAdult  startYear endYear  runtimeMinutes                    genres
# 0        0       1894      \N               1         Documentary,Short
# 1        0       1892      \N               5           Animation,Short
# 2        0       1892      \N               4  Animation,Comedy,Romance
# 3        0       1892      \N              12           Animation,Short

# %%
filters =["movie"]
title_basics_movie = title_basics[title_basics.titleType.isin(filters)]

# %%
import numpy as np

# %%
title_basics["flag"] = np.where(title_basics["primaryTitle"]==title_basics["originalTitle"],1, 0)

# %%
title_basics["flag"].value_counts()[0]/len(title_basics["flag"])*100
# Out:
# 16.2

# %%
list(title_basics_movie.columns)
# Out:
# ['tconst',
#  'titleType',
#  'primaryTitle',
#  'originalTitle',
#  'isAdult',
#  'startYear',
#  'endYear',
#  'runtimeMinutes',
#  'genres']

# %%
len(title_basics_movie)
# Out:
# 26

# %%
title_basics_movie = title_basics_movie[['tconst',
 'titleType',
 'primaryTitle',
 'startYear',
 'runtimeMinutes',
 'genres']]

# %%
title_basics
# Out:
#         tconst titleType                                       primaryTitle  \
# 0    tt0000001     short                                         Carmencita
# 1    tt0000002     short                             Le clown et ses chiens
# 2    tt0000003     short                                     Pauvre Pierrot
# 3    tt0000004     short                                        Un bon bock
# 4    tt0000005     short                                   Blacksmith Scene
# ..         ...       ...                                                ...
# 995  tt0001007     movie                       La primera y segunda casetas
# 996  tt0001008     short                          The Prince and the Pauper
# 997  tt0001009     short             Princess Nicotine; or, the Smoke Fairy
# 998  tt0001010     movie  Protección de un convoy de víveres en el puent...
# 999  tt0001011     short                                   The Prussian Spy
#
# ...

# %%
title_basics_movie[title_basics_movie.tconst=='tt0000147']
# Out:
#         tconst titleType                   primaryTitle  startYear  \
# 144  tt0000147     movie  The Corbett-Fitzsimmons Fight       1897
#
#     runtimeMinutes                  genres
# 144            100  Documentary,News,Sport

# %%
title_basics_movie.to_csv("title.basics.movie.tsv", sep="\t", header=True, index = None)

# %%
title_ratings =  pd.read_table('title.ratings.tsv/data.tsv',nrows=400).reset_index()

# %%
title_ratings.head(10)
# Out:
#    index     tconst  averageRating  numVotes
# 0      0  tt0000001            5.7      1949
# 1      1  tt0000002            5.8       264
# 2      2  tt0000003            6.5      1781
# 3      3  tt0000004            5.6       179
# 4      4  tt0000005            6.2      2581
# 5      5  tt0000006            5.1       177
# 6      6  tt0000007            5.4       811
# 7      7  tt0000008            5.4      2091
# 8      8  tt0000009            5.3       204
# 9      9  tt0000010            6.9      7050

# %%
        for id, row in title_basics_movie.iterrows():
            print(row)
            item =(row.tconst,row.titleType, row.primaryTitle,row.startYear, row.runtimeMinutes,row.genres )
# Out:
# tconst             tt0000009
# titleType              movie
# primaryTitle      Miss Jerry
# startYear               1894
# runtimeMinutes            45
# genres               Romance
# Name: 8, dtype: object
# tconst                                tt0000147
# titleType                                 movie
# primaryTitle      The Corbett-Fitzsimmons Fight
# startYear                                  1897
# runtimeMinutes                              100
# genres                   Documentary,News,Sport
# Name: 144, dtype: object
# tconst            tt0000502
# titleType             movie
# primaryTitle       Bohemios
# startYear              1905
# runtimeMinutes          100
# genres                   \N
# Name: 498, dtype: object
# tconst                              tt0000574
# titleType                               movie
# primaryTitle      The Story of the Kelly Gang
# startYear                                1906
# runtimeMinutes                             70
# ...
